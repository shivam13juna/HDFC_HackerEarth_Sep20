# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import lightgbm as lgb


#importing machine learning libraries
import tensorflow as tf
# from tensorflow.kears.models import In
from tensorflow.keras.layers import Dense, LSTM, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pickle



#Secondary imports
import pandas_profiling as pp

# %% [markdown]
# ## Reading Datasets

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')
# Out:
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (700,731,740,752,761,789,811,820,829,841,850) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pp_train = pp.ProfileReport(train)
pp_test = pp.ProfileReport(test)

pp_train.to_file('train_analysis.html')
pp_test.to_file('test_analysis.html')
# Out:
# /usr/local/lib/python3.5/site-packages/pandas_profiling/__init__.py:53: UserWarning: Sorting is supported from Python 3.6+
#   warnings.warn("Sorting is supported from Python 3.6+")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-075eb893ce18> in <module>
# ----> 1 pp_train = pp.ProfileReport(train)
#       2 pp_test = pp.ProfileReport(test)
#       3
#       4 pp_train.to_file('train_analysis.html')
#       5 pp_test.to_file('test_analysis.html')
#
# /usr/local/lib/python3.5/site-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      66
#      67         # Get dataset statistics
# ---> 68         description_set = describe_df(df)
#      69
#      70         # Get sample
#
# /usr/local/lib/python3.5/site-packages/pandas_profiling/model/describe.py in describe(df)
#     549
#     550     # Get correlations
# --> 551     correlations = calculate_correlations(df, variables)
#     552
#     553     # Check correlations between numerical variables
#
# /usr/local/lib/python3.5/site-packages/pandas_profiling/model/correlations.py in calculate_correlations(df, variables)
#     182
#     183             try:
# --> 184                 correlations["phi_k"] = df[selcols].phik_matrix(interval_cols=intcols)
#     185
#     186                 # Only do this if the column_order is set
#
# /usr/local/lib/python3.5/site-packages/phik/phik.py in phik_matrix(df, interval_cols, bins, quantile, noise_correction, dropna, drop_underflow, drop_overflow)
#     152     df_clean, interval_cols_clean = dq_check_nunique_values(df, interval_cols, dropna=dropna)
#     153
# --> 154     data_binned, binning_dict = bin_data(df_clean, cols=interval_cols_clean, bins=bins, quantile=quantile, retbins=True)
#     155     return phik_from_rebinned_df(data_binned, noise_correction, dropna=dropna, drop_underflow=drop_underflow,
#     156                                  drop_overflow=drop_overflow)
#
# /usr/local/lib/python3.5/site-packages/phik/binning.py in bin_data(data, cols, bins, quantile, retbins)
#     126             elif isinstance(bins[col], (list, np.ndarray)):
#     127                 xbins = bins[col]
# --> 128         binned_data[col], bin_labels = bin_array(data[col].astype(float).values, xbins)
#     129         if retbins:
#     130             bins_dict[col] = bin_labels
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1082                 else:
#    1083                     self._blklocs[blk.mgr_locs.indexer] = -1
# -> 1084                     blk.delete(blk_locs)
#    1085                     self._blklocs[blk.mgr_locs.indexer] = np.arange(len(blk))
#    1086
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals/blocks.py in delete(self, loc)
#     347         Delete given loc(-s) from block in-place.
#     348         """
# --> 349         self.values = np.delete(self.values, loc, 0)
#     350         self.mgr_locs = self.mgr_locs.delete(loc)
#     351
#
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py in delete(arr, obj, axis)
#    4416         keep[obj, ] = False
#    4417         slobj[axis] = keep
# -> 4418         new = arr[tuple(slobj)]
#    4419
#    4420     if wrap:
#
# KeyboardInterrupt:

# %%
lgbb = lgb.LGBMClassifier()
lgbb.fit(trainx, trainy)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
test.columns
# Out:
# Index(['Col1', 'Col3', 'Col4', 'Col5', 'Col6', 'Col7', 'Col8', 'Col9', 'Col10',
#        'Col11',
#        ...
#        'Col2388', 'Col2389', 'Col2390', 'Col2391', 'Col2392', 'Col2393',
#        'Col2394', 'Col2395', 'Col2396', 'Col2397'],
#       dtype='object', length=2394)

# %%
train.columns
# Out:
# Index(['Col1', 'Col2', 'Col3', 'Col4', 'Col5', 'Col6', 'Col7', 'Col8', 'Col9',
#        'Col10',
#        ...
#        'Col2388', 'Col2389', 'Col2390', 'Col2391', 'Col2392', 'Col2393',
#        'Col2394', 'Col2395', 'Col2396', 'Col2397'],
#       dtype='object', length=2395)

# %%
train.fillna(train.mean(), inplace=True)

# %%
test.fillna(test.mean(), inplace=True)

# %%
from scipy.stats import pearsonr

# %%
pearsonr(test['Col3'][:15000], train['Col3'][:15000])
# Out:
# (0.0015531277444954424, 0.8491502276512757)

# %%
the_list = []
for i in range(2, len(train.columns)):
    try:
        if round(pearsonr(test[train.columns[i]][:15000], train[train.columns[i]][:15000])[0], 2) > 0.02:
            print("This is the value for column:", train.columns[i], round(pearsonr(test[train.columns[i]][:15000], train[train.columns[i]][:15000])[0], 2))
            the_list.append(train.columns[i])
            
    except:
        pass
#         print("Couldn't do it for :", train.columns[i])
# Out:
# This is the value for column: Col17 0.03
# This is the value for column: Col192 0.03
# This is the value for column: Col389 0.03
# This is the value for column: Col400 0.03
# This is the value for column: Col585 0.03
# This is the value for column: Col878 0.03

# %%
train[the_list].reset_index()
# Out:
#        index     Col17      Col192      Col389        Col400      Col585  \
# 0          0  0.548538    0.500000    0.500000  4.269167e+03    0.000000
# 1          1  1.167898    4.200000    4.200000  3.191776e+05    7.000000
# 2          2  1.145182    7.600000    7.600000  2.555506e+05    5.333333
# 3          3  1.204010    6.600000    6.600000  2.984598e+05    8.666667
# 4          4  1.077682  147.600000  147.600000  3.454484e+07  242.000000
# 5          5  1.305899    7.500000    7.500000  1.552925e+06   10.000000
# 6          6  1.000000    0.142857    0.166667  4.166667e+03    0.000000
# 7          7  0.998686    1.571429    1.833333  6.195050e+04    2.333333
# 8          8  0.820135    0.000000    0.000000  0.000000e+00    0.000000
# 9          9  1.000000    0.000000    0.000000  0.000000e+00    0.000000
# 10        10  0.979536    0.000000    0.000000  0.000000e+00    0.000000
# 11        11  1.250000    0.000000    0.000000  0.000000e+00    0.000000
# 12        12  1.136372    0.166667    0.166667  9.583333e+02    0.333333
# 13        13  0.206824    0.428571    0.500000  8.400000e+04    0.000000
# 14        14  0.980224    0.000000    0.000000  0.000000e+00    0.000000
# 15        15  1.200000    0.333333    0.333333  1.977000e+03    0.666667
# 16        16  1.150547    0.285714    0.333333  5.973667e+03    0.333333
# 17        17  1.000000    0.800000    0.800000  1.053400e+04    0.666667
# 18        18  1.000000    0.833333    0.833333  4.166667e+03    1.666667
# 19        19  1.333054    0.500000    0.500000  5.000000e+03    0.666667
# 20        20  1.200000    0.000000    0.000000  0.000000e+00    0.000000
# 21        21  1.082766    0.000000    0.000000  0.000000e+00    0.000000
# 22        22  1.000000    0.000000    0.000000  0.000000e+00    0.000000
# 23        23  1.166710    0.000000    0.000000  0.000000e+00    0.000000
# 24        24  1.000000    0.000000    0.000000  0.000000e+00    0.000000
# 25        25  1.250000    0.000000    0.000000  0.000000e+00    0.000000
# 26        26  0.896494    0.166667    0.166667  1.666667e+03    0.333333
# 27        27  1.183184    0.600000    0.600000  5.821000e+03    1.000000
# 28        28  0.902454    0.000000    0.000000  0.000000e+00    0.000000
# 29        29  1.124761    0.000000    0.000000  0.000000e+00    0.000000
# ...      ...       ...         ...         ...           ...         ...
# 17491  17491  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17492  17492  0.945397    0.250000    0.250000  7.500000e+02    0.333333
# 17493  17493  0.760667    0.250000    0.250000  6.250000e+03    0.333333
# 17494  17494  1.122268    0.000000    0.000000  0.000000e+00    0.000000
# 17495  17495  1.316792    0.000000    0.000000  0.000000e+00    0.000000
# 17496  17496  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17497  17497  1.143829    0.000000    0.000000  0.000000e+00    0.000000
# 17498  17498  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17499  17499  1.089277    1.750000    1.750000  3.109150e+04    1.666667
# 17500  17500  1.205610    0.000000    0.000000  0.000000e+00    0.000000
# 17501  17501  1.333333    0.000000    0.000000  0.000000e+00    0.000000
# 17502  17502  1.333333    0.000000    0.000000  0.000000e+00    0.000000
# 17503  17503  0.914135    0.000000    0.000000  0.000000e+00    0.000000
# 17504  17504  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17505  17505  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17506  17506  1.333333    0.000000    0.000000  0.000000e+00    0.000000
# 17507  17507  1.051466    0.750000    0.750000  2.239250e+04    1.000000
# 17508  17508  1.333333    0.000000    0.000000  0.000000e+00    0.000000
# 17509  17509  1.100000    0.000000    0.000000  0.000000e+00    0.000000
# 17510  17510  1.198364    0.000000    0.000000  0.000000e+00    0.000000
# 17511  17511  1.077682    0.000000    0.000000  0.000000e+00    0.000000
# 17512  17512  1.077682   30.500000   30.500000  5.959563e+06   40.666667
# 17513  17513  1.077682    4.000000    4.000000  1.570812e+05    5.666667
# 17514  17514  1.090407    0.000000    0.000000  0.000000e+00    0.000000
# 17515  17515  0.985812    0.000000    0.000000  0.000000e+00    0.000000
# 17516  17516  1.000000    0.500000    0.500000  1.316667e+04    0.666667
# 17517  17517  1.084643    1.833333    1.833333  4.910767e+04    2.333333
# 17518  17518  1.250000    0.000000    0.000000  0.000000e+00    0.000000
# 17519  17519  1.000000    0.142857    0.166667  1.666667e+04    0.000000
# 17520  17520  1.000000    0.000000    0.000000  0.000000e+00    0.000000
#
#            Col878
# 0       39.000000
# 1       47.000000
# 2       24.000000
# 3        8.000000
# 4        5.000000
# 5       41.000000
# 6       31.000000
# 7       28.000000
# 8       31.000000
# 9       61.000000
# 10      51.000000
# 11      32.000000
# 12      23.000000
# 13      39.000000
# 14      51.000000
# 15      18.000000
# 16      43.000000
# 17      44.000000
# 18     155.000000
# 19      31.000000
# 20      30.000000
# 21      52.000000
# 22      30.000000
# 23      26.000000
# 24      30.000000
# 25      34.000000
# 26      20.000000
# 27      36.000000
# 28      22.000000
# 29      41.000000
# ...           ...
# 17491   11.000000
# 17492   18.000000
# 17493   53.000000
# 17494   24.000000
# 17495   21.000000
# 17496   32.000000
# 17497   15.000000
# 17498   33.649264
# 17499   13.000000
# 17500   19.000000
# 17501   33.000000
# 17502   23.000000
# 17503   31.000000
# 17504   33.649264
# 17505   33.649264
# 17506    1.000000
# 17507   43.000000
# 17508   33.000000
# 17509   36.000000
# 17510   33.000000
# 17511   40.000000
# 17512   23.000000
# 17513   13.000000
# 17514   58.000000
# 17515   20.000000
# 17516   76.000000
# 17517   70.000000
# 17518   58.000000
# 17519   35.000000
# 17520   66.000000
#
# [17521 rows x 7 columns]

# %%
train_data = train[the_list].values
test_data = test[the_list].values

# %%
np.shape(train_data)
# Out:
# (17521, 6)

# %%
lgbb = lgb.LGBMClassifier()
lgbb.fit(train_data, train['Col2'].values)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
result = lgbb.predict(test_data)

# %%
submission = pd.DataFrame()
submission['Col1'] = test['Col1']
submission['Col2'] = result

# %%
submission.to_csv('submission.csv', index=False)

# %%
submission.head()
# Out:
#         Col1  Col2
# 0  RIGD58ZWD     0
# 1  RIH660YDS     0
# 2  RIH660Q96     0
# 3  RIYDO15W1     0
# 4  RIYBGC1ZD     0

# %%
submission['Col2'].value_counts()
# Out:
# 0    20288
# 1      154
# Name: Col2, dtype: int64

# %%
train['Col2'].value_counts()
# Out:
# 0    15760
# 1     1761
# Name: Col2, dtype: int64

# %%
154/20288
# Out:
# 0.007590694006309148

# %%
1761/15760
# Out:
# 0.11173857868020305
